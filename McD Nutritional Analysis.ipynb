# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/Afzalkhan.pathan/Nutrical Dataset.csv")
print(data.info())

# As per below data is clean and there are no missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
data.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
# Analysing the distribution of calorie counts
plt.figure(figsize=(10, 6))
sns.histplot(data['Calories'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Calorie Counts')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %%
nutritional_columns = ['Total Fat (% Daily Value)', 'Saturated Fat (% Daily Value)', 'Cholesterol (% Daily Value)', 
                       'Sodium (% Daily Value)', 'Carbohydrates (% Daily Value)', 'Dietary Fiber (% Daily Value)', 
                       'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 
                       'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# %%
nutritional_data = data[nutritional_columns]

# %%
# Calculating the mean nutritional content
mean_nutritional_data = nutritional_data.mean()

# Plotting the mean nutritional content as a bar chart
plt.figure(figsize=(10, 6))
mean_nutritional_data.plot(kind='bar', color='skyblue')
plt.title('Mean Nutritional Content of Menu Items')
plt.xlabel('Nutritional Component')
plt.ylabel('Amount (g/mg)')
plt.xticks(rotation=45)
plt.show()

# %%
# Comparing nutritional characteristics of different food categories
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Calories', data=data, palette='husl')
plt.title('Average Calorie Count by Category')
plt.xlabel('Category')
plt.ylabel('Average Calories')
plt.xticks(rotation=45)
plt.show()

# %%
# Identifying menu items with the highest and lowest calorie counts
highest_calories = data[data['Calories'] == data['Calories'].max()]
lowest_calories = data[data['Calories'] == data['Calories'].min()]

print("Menu item with the highest calorie count:")
print(highest_calories[['Category', 'Item', 'Calories']])
print("\nMenu item with the lowest calorie count:")
print(lowest_calories[['Category', 'Item', 'Calories']])

# Determining the average nutritional content of popular menu categories
avg_nutritional_content = data.groupby('Category')[nutritional_columns].mean()
print("\nAverage Nutritional Content by Category:")
print(avg_nutritional_content)
# Out:
# Menu item with the highest calorie count:
#           Category                          Item  Calories
# 82  Chicken & Fish  Chicken McNuggets (40 piece)      1880
#
# Menu item with the lowest calorie count:
#          Category                     Item  Calories
# 114     Beverages        Diet Coke (Small)         0
# 115     Beverages       Diet Coke (Medium)         0
# 116     Beverages        Diet Coke (Large)         0
# 117     Beverages        Diet Coke (Child)         0
# 122     Beverages   Diet Dr Pepper (Small)         0
# 123     Beverages  Diet Dr Pepper (Medium)         0
# 124     Beverages   Diet Dr Pepper (Large)         0
# 125     Beverages   Diet Dr Pepper (Child)         0
# 136     Beverages      Dasani Water Bottle         0
# 137  Coffee & Tea         Iced Tea (Small)         0
# 138  Coffee & Tea        Iced Tea (Medium)         0
# 139  Coffee & Tea         Iced Tea (Large)         0
# 140  Coffee & Tea         Iced Tea (Child)         0
# ...

# %%
# Identify menu items with the highest and lowest sugar counts
highest_calories = data[data['Sugars'] == data['Sugars'].max()]
lowest_calories = data[data['Sugars'] == data['Sugars'].min()]
print("Menu item with the highest calorie count:")
print(highest_calories[['Category', 'Item', 'Sugars']])
print("\nMenu item with the lowest calorie count:")
print(lowest_calories[['Category', 'Item', 'Sugars']])
# Out:
# Menu item with the highest calorie count:
#                Category                                  Item  Sugars
# 253  Smoothies & Shakes  McFlurry with M&M’s Candies (Medium)     128
#
# Menu item with the lowest calorie count:
#            Category                          Item  Sugars
# 38        Breakfast                    Hash Brown       0
# 78   Chicken & Fish   Chicken McNuggets (4 piece)       0
# 79   Chicken & Fish   Chicken McNuggets (6 piece)       0
# 80   Chicken & Fish  Chicken McNuggets (10 piece)       0
# 81   Chicken & Fish  Chicken McNuggets (20 piece)       0
# 96   Snacks & Sides            Small French Fries       0
# 97   Snacks & Sides           Medium French Fries       0
# 98   Snacks & Sides            Large French Fries       0
# 99   Snacks & Sides             Kids French Fries       0
# 114       Beverages             Diet Coke (Small)       0
# 115       Beverages            Diet Coke (Medium)       0
# ...

# %%
# Combine calorie counts and nutritional data into a single DataFrame
combined_data = pd.concat([data['Calories'], nutritional_data], axis=1)

# Plotting box plots for calorie distribution and nutritional content
plt.figure(figsize=(12, 6))
sns.boxplot(data=combined_data, orient='v', palette='Set2')
plt.title('Calorie Distribution and Nutritional Content of Menu Items')
plt.ylabel('Amount (g/mg/kcal)')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculating the average cholesterol content by category
average_cholesterol_by_category = data.groupby('Category')['Cholesterol'].mean().sort_values(ascending=False)

print("Average Cholesterol Content by Category:")
print(average_cholesterol_by_category)
# Out:
# Average Cholesterol Content by Category:
# Category
# Breakfast             152.857143
# Beef & Pork            87.333333
# Chicken & Fish         75.370370
# Salads                 51.666667
# Smoothies & Shakes     45.000000
# Coffee & Tea           27.263158
# Snacks & Sides         18.461538
# Desserts               15.000000
# Beverages               0.555556
# Name: Cholesterol, dtype: float64

# %%
# item with the highest dietary fiber content
highest_fiber_item = data[data['Dietary Fiber'] == data['Dietary Fiber'].max()]

print("Item with the Highest Dietary Fiber:")
print(highest_fiber_item[['Category', 'Item', 'Dietary Fiber']])
# Out:
# Item with the Highest Dietary Fiber:
#      Category                                               Item  \
# 32  Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 88     Salads        Premium Southwest Salad with Crispy Chicken
# 89     Salads       Premium Southwest Salad with Grilled Chicken
#
#     Dietary Fiber
# 32              7
# 34              7
# 88              7
# 89              7

# %%
#items which have protein above 15, sugar below 15 and cholesterol below 70
filtered_data = data[(data['Sugars'] < 15) & (data['Cholesterol'] < 70) & (data['Protein'] > 15) & (data['Calories'] <= 500)]

# Sort the filtered data by protein levels in descending order
top_10_items = filtered_data.sort_values(by='Protein', ascending=False).head(10)

print("Top 10 Items with Low Sugar and Cholesterol, High Protein, and Maximum Calories of 500:")
print(top_10_items[['Category', 'Item', 'Sugars', 'Cholesterol', 'Protein', 'Calories']])
# Out:
# Top 10 Items with Low Sugar and Cholesterol, High Protein, and Maximum Calories of 500:
#           Category                                               Item  Sugars  \
# 58  Chicken & Fish           Premium Grilled Chicken Classic Sandwich       8
# 77  Chicken & Fish  Premium McWrap Chicken Sweet Chili (Grilled Ch...      12
# 88          Salads        Premium Southwest Salad with Crispy Chicken      12
# 80  Chicken & Fish                       Chicken McNuggets (10 piece)       0
# 67  Chicken & Fish                            Bacon Cheddar McChicken       6
# 65  Chicken & Fish             Southern Style Crispy Chicken Sandwich       7
# 4        Breakfast                   Sausage McMuffin with Egg Whites       2
# 68  Chicken & Fish                      Bacon Buffalo Ranch McChicken       6
# 8        Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...       3
# 9        Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...       4
#
# ...

# %%
# Filter non-beverage items
food_items = data[~data['Category'].isin(['Coffee & Tea', 'Beverages','Smoothies & Shakes'])]

# Select food items with sodium level below 1500
top_food_items_below_1500 = food_items[food_items['Sodium'] < 1500]

# Sort the selected food items by sodium level in ascending order
top_food_items_below_1500 = top_food_items_below_1500.sort_values(by='Sodium')

print("Top Food Items with Sodium Level Below 1500:")
print(top_food_items_below_1500[['Category', 'Item', 'Sodium']].head(10))
# Out:
# Top Food Items with Sodium Level Below 1500:
#            Category                                       Item  Sodium
# 101  Snacks & Sides                               Apple Slices       0
# 100  Snacks & Sides                                 Side Salad      10
# 106        Desserts                        Kids Ice Cream Cone      20
# 99   Snacks & Sides                          Kids French Fries      65
# 102  Snacks & Sides                    Fruit 'n Yogurt Parfait      70
# 109        Desserts                          Strawberry Sundae      85
# 104        Desserts                      Chocolate Chip Cookie      90
# 41        Breakfast  Fruit & Maple Oatmeal without Brown Sugar     115
# 96   Snacks & Sides                         Small French Fries     130
# 105        Desserts                      Oatmeal Raisin Cookie     135

# %%
# Filter for categories 'Coffee & Tea', 'Beverages', and 'Smoothies & Shakes'
selected_categories = ['Coffee & Tea', 'Beverages', 'Smoothies & Shakes']
selected_items = data[data['Category'].isin(selected_categories)]

# Select items with sodium level below 1500
items_below_1500_sodium = selected_items[selected_items['Sodium'] < 1500]

print("Items in 'Coffee & Tea', 'Beverages', and 'Smoothies & Shakes' with Sodium Level Below 1500:")
print(items_below_1500_sodium[['Category', 'Item', 'Sodium']])
# Out:
# Items in 'Coffee & Tea', 'Beverages', and 'Smoothies & Shakes' with Sodium Level Below 1500:
#                Category                                               Item  \
# 110           Beverages                          Coca-Cola Classic (Small)
# 111           Beverages                         Coca-Cola Classic (Medium)
# 112           Beverages                          Coca-Cola Classic (Large)
# 113           Beverages                          Coca-Cola Classic (Child)
# 114           Beverages                                  Diet Coke (Small)
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# ...

# %%
# Sort by protein content in descending order
highest_protein_items = data.sort_values(by='Protein', ascending=False)

# items with the highest protein content
print("Items with the Highest Protein Content:")
print(highest_protein_items[['Item', 'Category', 'Protein']].head(10))
# Out:
# Items with the Highest Protein Content:
#                                                 Item        Category  Protein
# 82                      Chicken McNuggets (40 piece)  Chicken & Fish       87
# 47                Double Quarter Pounder with Cheese     Beef & Pork       48
# 81                      Chicken McNuggets (20 piece)  Chicken & Fish       44
# 60             Premium Grilled Chicken Club Sandwich  Chicken & Fish       40
# 64          Bacon Clubhouse Grilled Chicken Sandwich  Chicken & Fish       40
# 51                            Bacon Clubhouse Burger     Beef & Pork       39
# 44               Quarter Pounder with Bacon & Cheese     Beef & Pork       37
# 45         Quarter Pounder with Bacon Habanero Ranch     Beef & Pork       37
# 71  Premium McWrap Chicken & Bacon (Grilled Chicken)  Chicken & Fish       36
# 63           Bacon Clubhouse Crispy Chicken Sandwich  Chicken & Fish       36

# %%
# Sort by sodium content in descending order
high_sodium_items = data.sort_values(by='Sodium', ascending=False)

# items with high sodium levels
print("Items with High Sodium Levels:")
print(high_sodium_items[['Item', 'Category', 'Sodium']].head(10))
# Out:
# Items with High Sodium Levels:
#                                                  Item        Category  Sodium
# 82                       Chicken McNuggets (40 piece)  Chicken & Fish    3600
# 34  Big Breakfast with Hotcakes and Egg Whites (La...       Breakfast    2290
# 32        Big Breakfast with Hotcakes (Large Biscuit)       Breakfast    2260
# 33  Big Breakfast with Hotcakes and Egg Whites (Re...       Breakfast    2170
# 31      Big Breakfast with Hotcakes (Regular Biscuit)       Breakfast    2150
# 81                       Chicken McNuggets (20 piece)  Chicken & Fish    1800
# 63            Bacon Clubhouse Crispy Chicken Sandwich  Chicken & Fish    1720
# 30      Big Breakfast with Egg Whites (Large Biscuit)       Breakfast    1700
# 28                      Big Breakfast (Large Biscuit)       Breakfast    1680
# 29    Big Breakfast with Egg Whites (Regular Biscuit)       Breakfast    1590

# %%
# Sort by Vitamin C content in descending order
high_vitamin_c_items = data.sort_values(by='Vitamin C (% Daily Value)', ascending=False)

# items with high Vitamin C levels
print("Items with High Vitamin C Levels:")
print(high_vitamin_c_items[['Item', 'Category', 'Vitamin C (% Daily Value)']].head(10))
# Out:
# Items with High Vitamin C Levels:
#                                           Item            Category  \
# 135           Minute Maid Orange Juice (Large)           Beverages
# 134          Minute Maid Orange Juice (Medium)           Beverages
# 101                               Apple Slices      Snacks & Sides
# 133           Minute Maid Orange Juice (Small)           Beverages
# 41   Fruit & Maple Oatmeal without Brown Sugar           Breakfast
# 40                       Fruit & Maple Oatmeal           Breakfast
# 132           Minute Maid 100% Apple Juice Box           Beverages
# 98                          Large French Fries      Snacks & Sides
# 237         Strawberry Banana Smoothie (Large)  Smoothies & Shakes
# 97                         Medium French Fries      Snacks & Sides
#
#      Vitamin C (% Daily Value)
# 135                        240
# 134                        160
# 101                        160
# 133                        130
# 41                         130
# ...

# %%
# Sort by Iron content in descending order
iron_rich_items = data.sort_values(by='Iron (% Daily Value)', ascending=False)

#items rich in Iron
print("Items Rich in Iron:")
print(iron_rich_items[['Item', 'Category', 'Iron (% Daily Value)']].head(10))
# Out:
# Items Rich in Iron:
#                                                  Item        Category  \
# 31      Big Breakfast with Hotcakes (Regular Biscuit)       Breakfast
# 32        Big Breakfast with Hotcakes (Large Biscuit)       Breakfast
# 47                 Double Quarter Pounder with Cheese     Beef & Pork
# 34  Big Breakfast with Hotcakes and Egg Whites (La...       Breakfast
# 44                Quarter Pounder with Bacon & Cheese     Beef & Pork
# 46                             Quarter Pounder Deluxe     Beef & Pork
# 28                      Big Breakfast (Large Biscuit)       Breakfast
# 33  Big Breakfast with Hotcakes and Egg Whites (Re...       Breakfast
# 45          Quarter Pounder with Bacon Habanero Ranch     Beef & Pork
# 82                       Chicken McNuggets (40 piece)  Chicken & Fish
#
#     Iron (% Daily Value)
# 31                    40
# 32                    40
# 47                    35
# 34                    30
# 44                    30
# ...
